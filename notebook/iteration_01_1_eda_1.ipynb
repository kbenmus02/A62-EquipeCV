# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb

# %%
# %cd /content/drive/MyDrive/A62_projet_synthese_feature/notebook
# Out:
# /content/drive/MyDrive/A62_projet_synthese_feature/notebook

# %%
# %run iteration_01_0_imports.py

# %%
# %run iteration_01_0_parameters.py

# %%
# %whos #Affiche les variables et leurs valeurs
# Out:
# No variables match your requested type.

# %%
import iteration_01_0_utils as utils
# Out:
# importing Jupyter notebook from iteration_01_0_utils.ipynb

# %% [markdown]
# # Acquisition des données

# %%
# %whos
# Out:
# Variable           Type      Data/Info
# --------------------------------------
# HEALTHY            str       H
# IMG_SIZE           int       400
# Image              module    <module 'PIL.Image' from <...>t-packages/PIL/Image.py'>
# NBR_SAMPLE         int       2000
# PATH_DATA          str       ../data
# PATH_DATA_EDA      str       ../data/eda
# PATH_DATA_LIST     str       ../data/list
# PATH_DATA_SAMPLE   str       ../data/sample
# PATH_MODEL         str       ../model
# PATH_ROOT          str       ..
# PATH_SOURCE_IMG    str       /content/drive/MyDrive/A6<...>_synthese_lnk/cell_images
# SICK               str       S
# cv2                module    <module 'cv2.cv2' from '/<...>37m-x86_64-linux-gnu.so'>
# datetime           type      <class 'datetime.datetime'>
# drive              module    <module 'google.colab.dri<...>s/google/colab/drive.py'>
# glob               module    <module 'glob' from '/usr/lib/python3.7/glob.py'>
# import_ipynb       module    <module 'import_ipynb' fr<...>ackages/import_ipynb.py'>
# np                 module    <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# os                 module    <module 'os' from '/usr/lib/python3.7/os.py'>
# pd                 module    <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# pickle             module    <module 'pickle' from '/u<...>lib/python3.7/pickle.py'>
# plt                module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# random             module    <module 'random' from '/u<...>lib/python3.7/random.py'>
# sns                module    <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# tqdm               type      <class 'tqdm.std.tqdm'>
# utils              module    <module 'iteration_01_0_u<...>ject at 0x7f045f231f50>)>

# %%
path_img = PATH_SOURCE_IMG

# %%
# get list sick_images
list_path_sick_img = []
list_path_sick_img.extend(glob.glob(path_img+"/Parasitized/*.png"))

# get list healthy_images
list_path_healthy_img = []
list_path_healthy_img.extend(glob.glob(path_img+"/Uninfected/*.png"))

# %%
list_path_img = list_path_sick_img + list_path_healthy_img
len(list_path_img)
# Out:
# 50

# %%
df_list_path_img = pd.DataFrame({"path_img": list_path_img})
df_list_path_sick_img = pd.DataFrame({"path_img": list_path_sick_img})
df_list_path_healthy_img = pd.DataFrame({"path_img": list_path_healthy_img})

# %%
df_list_path_img.shape
# Out:
# (50, 1)

# %%
df_list_path_sick_img.shape
# Out:
# (25, 1)

# %%
df_list_path_healthy_img.shape
# Out:
# (25, 1)

# %%
PATH_DATA_LIST
# Out:
# '../data/list'

# %%
os.makedirs(PATH_DATA_LIST, exist_ok=True)

# %%
df_list_path_img.to_csv(PATH_DATA_LIST + "/" + "df_list_path_img.csv", index=False)
df_list_path_sick_img.to_csv(PATH_DATA_LIST + "/" + "df_list_path_sick_img.csv", index=False)
df_list_path_healthy_img.to_csv(PATH_DATA_LIST + "/" + "df_list_path_healthy_img.csv", index=False)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Dimensions des photos

# %%
df_eda = pd.DataFrame(columns = ["name", "label", "width", "height"])

for path_img, _ in zip(list_path_img, tqdm(range(len(list_path_img)))):
    img     = Image.open(path_img)
    file_path, file_name, _ = utils.split_file_info(path_img)
    
    df_img_info = pd.DataFrame({"name":file_name,
                                "label":file_path.split("/")[-1],
                                "width": img.size[0],
                                "height":img.size[1],
                                }, index=[0])
    
    df_eda = pd.concat([df_eda, df_img_info])
# Out:
#  98%|█████████▊| 49/50 [00:15<00:00,  3.24it/s]

# %%
df_eda[["width", "height"]] = df_eda[["width", "height"]].astype("int")

# %%
df_eda.sample(5)
# Out:
#                                        name        label  width  height
# 0      C1_thinF_IMG_20150604_104722_cell_15   Uninfected    121     106
# 0     C1_thinF_IMG_20150604_104722_cell_211   Uninfected    112     145
# 0  C33P1thinF_IMG_20150619_121229a_cell_177  Parasitized    115     121
# 0     C1_thinF_IMG_20150604_104722_cell_248   Uninfected    139     130
# 0  C33P1thinF_IMG_20150619_121300a_cell_156  Parasitized    130     124

# %%
df_eda.describe()
# Out:
#             width      height
# count   50.000000   50.000000
# mean   132.640000  128.980000
# std     12.489604   16.416132
# min    103.000000  100.000000
# 25%    127.000000  115.000000
# 50%    131.500000  128.500000
# 75%    139.000000  141.250000
# max    157.000000  163.000000

# %% [markdown]
# * Note: Resize 400 * 400

# %%
import os

# %%
PATH_DATA_EDA
# Out:
# '../data/eda'

# %%
os.makedirs(PATH_DATA_EDA, exist_ok=True)

# %%
df_eda.to_csv(PATH_DATA_EDA + "/" + "df_eda.csv", index=False)
